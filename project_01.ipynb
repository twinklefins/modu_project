# %%
# 1. 사각형 넓이 구하기

class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요. \n 1. 직사각형 2. 평행사변형 3. 사다리꼴'))

        if self.square == 1:
            print('직사각형 함수는 rect() 입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par() 입니다.')

        elif self.square == 3:
            print('사다리꼴 함수는 trape() 입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요.')

    def rect(self):
        width, height = map(int, input('가로, 세로를 입력하세요. \n예시: 가로, 세로 \n>>> ').split(','))
        area = width * height
        result = '직사각형의 넓이는: ' + str(area)
        return result

    def par(self):
        lower, height = map(int, input('밑변, 높이를 입력하세요. \n예시: 밑변, 높이 \n>>> ').split(','))
        area = lower * height
        result = '평행사변형의 넓이는: ' + str(area)
        return result
    
    def trape(self):
        top, bottom, height = map(int, input('윗변, 아랫변, 높이를 입력하세요. \n예시: 윗변, 아랫변, 높이 \n>>> ').split(','))
        area = (top + bottom) * height / 2
        result = '사다리꼴의 넓이는: ' + str(area)
        return result

a = Square()
a.rect()
# Out:
# 직사각형 함수는 rect() 입니다.
# '직사각형의 넓이는: 5'

# %%
# 2. 키오스크(Kiosk) 만들기

class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]
        self.order_menu = []
        self.order_price = []
        self.price_sum = 0

    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    def menu_select(self):
        print()
        n = 0

        while n < 1 or len(self.menu) < n:
            n = int(input("음료의 번호를 입력하세요. : "))      
            if 1 <= n and n <= len(self.menu):
                self.price_sum = self.price[n-1]
                self.order_price.append(self.price[n-1])
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        t = 0
        while t != 1 and t != 2:
            t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요. : "))
            if t == 1:
                self.temp = 'HOT'
            elif t == 2:
                self.temp = 'ICE'
            else:
                print("1과 2 중 하나를 입력하세요.\n")
        
        self.order_menu.append(self.temp + ' ' + self.menu[n-1])
        print('주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')

        while n != 0:
            print()
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요. : "))
            if n > 0 and n < len(self.menu) + 1:

                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요. : "))
                    if t == 1:
                        self.temp = 'HOT'
                    elif t == 2:
                        self.temp = 'ICE'
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")

            self.order_menu.append(self.temp + ' ' + self.menu[n-1])
            self.order_price.append(self.price[n-1])
            self.price_sum += self.price[n-1]

            print('추가 주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원\n', '합계 : ', self.price_sum, '원')
            
        else:
            if n == 0:
                print("\n주문이 완료되었습니다.")
                print(self.order_menu, self.order_price)
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")

    def pay(self):
        print(f"\n총 합계 금액은 {self.price_sum}원 입니다.")
    
        self.pay_method = 0 
        while self.pay_method != 1 and self.pay_method !=2:
            self.pay_method = int(input("현금결재는 1을, 카드결제는 2를 입력해 주세요. : "))
            if self.pay_method == 1:
                print("\n직원을 호출하겠습니다.")
            elif self.pay_method == 2:
                print("\nIC칩 방향에 맞게 카드를 꽂아주세요.")
            else: 
                print("다시 결제를 시도해 주세요.")
    
    def table(self):
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        for i in range(len(self.order_menu)):
            print(self.order_menu[i], " : ", self.order_price[i])

        print("합계 금액 : ", self.price_sum)

        for i in range(5):
            print('|' + ' ' * 31 + '|')
        print('⟝' + '-' * 30 + '⟞')



a = Kiosk()
a.menu_print()
a.menu_select()
a.pay()
a.table()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 주문 음료 ICE mocha  :  3000 원
#
# 추가 주문 음료 HOT latte  :  3000 원
#  합계 :  6000 원
#
# 추가 주문 음료 ICE americano  :  2000 원
#  합계 :  8000 원
#
# 추가 주문 음료 HOT green_tea  :  2500 원
#  합계 :  10500 원
#
# 추가 주문 음료 HOT choco_latte  :  3000 원
#  합계 :  13500 원
#
# 주문이 완료되었습니다.
# ['ICE mocha', 'HOT latte', 'ICE americano', 'HOT green_tea', 'HOT choco_latte'] [3000, 3000, 2000, 2500, 3000]
#
# 총 합계 금액은 13500원 입니다.
#
# IC칩 방향에 맞게 카드를 꽂아주세요.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE mocha  :  3000
# HOT latte  :  3000
# ICE americano  :  2000
# HOT green_tea  :  2500
# HOT choco_latte  :  3000
# 합계 금액 :  13500
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
